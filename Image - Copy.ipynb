# %% [markdown]
# Like

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Load CSV
df = pd.read_csv('Like.csv')

# Dynamically identify relevant columns
query_col = next(col for col in df.columns if 'query' in col.lower())
sample_col = next(col for col in df.columns if 'db' in col.lower() or 'database' in col.lower())
error_col = next(col for col in df.columns if 'error' in col.lower())
overhead_col = next(col for col in df.columns if 'overhead' in col.lower())

# Extract sample size (in MB) from sample database name
df['Sample_MB'] = df[sample_col].astype(str).str.extract(r'(\d+)').astype(float)

# Convert metrics to numeric
df[error_col] = pd.to_numeric(df[error_col], errors='coerce')
df[overhead_col] = pd.to_numeric(df[overhead_col], errors='coerce')

# Create output folder
output_folder = 'query'
os.makedirs(output_folder, exist_ok=True)

# Clean and deduplicate queries
df['Clean_Query'] = df[query_col].astype(str).str.strip()
unique_queries = df['Clean_Query'].drop_duplicates().reset_index(drop=True)

# Save queries to log file
queries_log_path = os.path.join(output_folder, 'queries_log.txt')
with open(queries_log_path, 'w') as f:
    for idx, query in unique_queries.items():
        f.write(f"Query {idx + 1}: {query}\n")

# Generate bar charts
for idx, query in unique_queries.items():
    sub = df[df['Clean_Query'] == query].sort_values('Sample_MB')

    x = np.arange(len(sub))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 6))
    bars1 = ax.bar(x - width / 2, sub[error_col], width, label='Relative Error (%)')
    bars2 = ax.bar(x + width / 2, sub[overhead_col], width, label='Speed Overhead (%)')

    ax.set_xlabel('Sample Size (MB)')
    ax.set_ylabel('Percentage')
    ax.set_title(f'Relative Error and Speed Overhead per Sample DB (Query {idx + 1})')
    ax.set_xticks(x)
    ax.set_xticklabels([f"{int(mb)}MB" for mb in sub['Sample_MB']])
    ax.legend()

    for bar in bars1 + bars2:
        height = bar.get_height()
        if not pd.isna(height):
            ax.annotate(f'{height:.1f}%',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3),
                        textcoords="offset points",
                        ha='center', va='bottom')

    plt.tight_layout()
    filename = f"query_{idx + 1}.png"
    filepath = os.path.join(output_folder, filename)
    plt.savefig(filepath)
    plt.show()

# %% [markdown]
# EQUAL Queries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Load CSV
df = pd.read_csv('Equal.csv')

# Dynamically identify relevant columns
query_col = next(col for col in df.columns if 'query' in col.lower())
sample_col = next(col for col in df.columns if 'db' in col.lower() or 'database' in col.lower())
error_col = next(col for col in df.columns if 'error' in col.lower())
overhead_col = next(col for col in df.columns if 'overhead' in col.lower())

# Extract sample size (in MB) from sample database name
df['Sample_MB'] = df[sample_col].astype(str).str.extract(r'(\d+)').astype(float)

# Convert metrics to numeric
df[error_col] = pd.to_numeric(df[error_col], errors='coerce')
df[overhead_col] = pd.to_numeric(df[overhead_col], errors='coerce')

# Create output folder
output_folder = 'query'
os.makedirs(output_folder, exist_ok=True)

# Clean and deduplicate queries
df['Clean_Query'] = df[query_col].astype(str).str.strip()
unique_queries = df['Clean_Query'].drop_duplicates().reset_index(drop=True)

# Save queries to log file
queries_log_path = os.path.join(output_folder, 'queries_log.txt')
with open(queries_log_path, 'w') as f:
    for idx, query in unique_queries.items():
        f.write(f"Query {idx + 1}: {query}\n")

# Generate bar charts
for idx, query in unique_queries.items():
    sub = df[df['Clean_Query'] == query].sort_values('Sample_MB')

    x = np.arange(len(sub))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 6))
    bars1 = ax.bar(x - width / 2, sub[error_col], width, label='Relative Error (%)')
    bars2 = ax.bar(x + width / 2, sub[overhead_col], width, label='Speed Overhead (%)')

    ax.set_xlabel('Sample Size (MB)')
    ax.set_ylabel('Percentage')
    ax.set_title(f'Relative Error and Speed Overhead per Sample DB (Query {idx + 1})')
    ax.set_xticks(x)
    ax.set_xticklabels([f"{int(mb)}MB" for mb in sub['Sample_MB']])
    ax.legend()

    for bar in bars1 + bars2:
        height = bar.get_height()
        if not pd.isna(height):
            ax.annotate(f'{height:.1f}%',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3),
                        textcoords="offset points",
                        ha='center', va='bottom')

    plt.tight_layout()
    filename = f"query_{idx + 1}.png"
    filepath = os.path.join(output_folder, filename)
    plt.savefig(filepath)
    plt.show()

# %% [markdown]
# Avg with range condition

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Load CSV
df = pd.read_csv('Avg.csv')

# Dynamically identify relevant columns
query_col = next(col for col in df.columns if 'query' in col.lower())
sample_col = next(col for col in df.columns if 'db' in col.lower() or 'database' in col.lower())
error_col = next(col for col in df.columns if 'error' in col.lower())
overhead_col = next(col for col in df.columns if 'overhead' in col.lower())

# Extract sample size (in MB) from sample database name
df['Sample_MB'] = df[sample_col].astype(str).str.extract(r'(\d+)').astype(float)

# Convert metrics to numeric
df[error_col] = pd.to_numeric(df[error_col], errors='coerce')
df[overhead_col] = pd.to_numeric(df[overhead_col], errors='coerce')

# Create output folder
output_folder = 'query'
os.makedirs(output_folder, exist_ok=True)

# Clean and deduplicate queries
df['Clean_Query'] = df[query_col].astype(str).str.strip()
unique_queries = df['Clean_Query'].drop_duplicates().reset_index(drop=True)

# Save queries to log file
queries_log_path = os.path.join(output_folder, 'queries_log.txt')
with open(queries_log_path, 'w') as f:
    for idx, query in unique_queries.items():
        f.write(f"Query {idx + 1}: {query}\n")

# Generate bar charts
for idx, query in unique_queries.items():
    sub = df[df['Clean_Query'] == query].sort_values('Sample_MB')

    x = np.arange(len(sub))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 6))
    bars1 = ax.bar(x - width / 2, sub[error_col], width, label='Relative Error (%)')
    bars2 = ax.bar(x + width / 2, sub[overhead_col], width, label='Speed Overhead (%)')

    ax.set_xlabel('Sample Size (MB)')
    ax.set_ylabel('Percentage')
    ax.set_title(f'Relative Error and Speed Overhead per Sample DB (Query {idx + 1})')
    ax.set_xticks(x)
    ax.set_xticklabels([f"{int(mb)}MB" for mb in sub['Sample_MB']])
    ax.legend()

    for bar in bars1 + bars2:
        height = bar.get_height()
        if not pd.isna(height):
            ax.annotate(f'{height:.1f}%',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3),
                        textcoords="offset points",
                        ha='center', va='bottom')

    plt.tight_layout()
    filename = f"query_{idx + 1}.png"
    filepath = os.path.join(output_folder, filename)
    plt.savefig(filepath)
    plt.show()

# %% [markdown]
# Sum

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Load CSV
df = pd.read_csv('Sum.csv')

# Dynamically identify relevant columns
query_col = next(col for col in df.columns if 'query' in col.lower())
sample_col = next(col for col in df.columns if 'db' in col.lower() or 'database' in col.lower())
error_col = next(col for col in df.columns if 'error' in col.lower())
overhead_col = next(col for col in df.columns if 'overhead' in col.lower())

# Extract sample size (in MB) from sample database name
df['Sample_MB'] = df[sample_col].astype(str).str.extract(r'(\d+)').astype(float)

# Convert metrics to numeric
df[error_col] = pd.to_numeric(df[error_col], errors='coerce')
df[overhead_col] = pd.to_numeric(df[overhead_col], errors='coerce')

# Create output folder
output_folder = 'query'
os.makedirs(output_folder, exist_ok=True)

# Clean and deduplicate queries
df['Clean_Query'] = df[query_col].astype(str).str.strip()
unique_queries = df['Clean_Query'].drop_duplicates().reset_index(drop=True)

# Save queries to log file
queries_log_path = os.path.join(output_folder, 'queries_log.txt')
with open(queries_log_path, 'w') as f:
    for idx, query in unique_queries.items():
        f.write(f"Query {idx + 1}: {query}\n")

# Generate bar charts
for idx, query in unique_queries.items():
    sub = df[df['Clean_Query'] == query].sort_values('Sample_MB')

    x = np.arange(len(sub))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 6))
    bars1 = ax.bar(x - width / 2, sub[error_col], width, label='Relative Error (%)')
    bars2 = ax.bar(x + width / 2, sub[overhead_col], width, label='Speed Overhead (%)')

    ax.set_xlabel('Sample Size (MB)')
    ax.set_ylabel('Percentage')
    ax.set_title(f'Relative Error and Speed Overhead per Sample DB (Query {idx + 1})')
    ax.set_xticks(x)
    ax.set_xticklabels([f"{int(mb)}MB" for mb in sub['Sample_MB']])
    ax.legend()

    for bar in bars1 + bars2:
        height = bar.get_height()
        if not pd.isna(height):
            ax.annotate(f'{height:.1f}%',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3),
                        textcoords="offset points",
                        ha='center', va='bottom')

    plt.tight_layout()
    filename = f"query_{idx + 1}.png"
    filepath = os.path.join(output_folder, filename)
    plt.savefig(filepath)
    plt.show()

# %% [markdown]
# Range Queries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Load CSV
df = pd.read_csv('Sum.csv')

# Dynamically identify relevant columns
query_col = next(col for col in df.columns if 'query' in col.lower())
sample_col = next(col for col in df.columns if 'db' in col.lower() or 'database' in col.lower())
error_col = next(col for col in df.columns if 'error' in col.lower())
overhead_col = next(col for col in df.columns if 'overhead' in col.lower())

# Extract sample size (in MB) from sample database name
df['Sample_MB'] = df[sample_col].astype(str).str.extract(r'(\d+)').astype(float)

# Convert metrics to numeric
df[error_col] = pd.to_numeric(df[error_col], errors='coerce')
df[overhead_col] = pd.to_numeric(df[overhead_col], errors='coerce')

# Create output folder
output_folder = 'query'
os.makedirs(output_folder, exist_ok=True)

# Clean and deduplicate queries
df['Clean_Query'] = df[query_col].astype(str).str.strip()
unique_queries = df['Clean_Query'].drop_duplicates().reset_index(drop=True)

# Save queries to log file
queries_log_path = os.path.join(output_folder, 'queries_log.txt')
with open(queries_log_path, 'w') as f:
    for idx, query in unique_queries.items():
        f.write(f"Query {idx + 1}: {query}\n")

# Generate bar charts
for idx, query in unique_queries.items():
    sub = df[df['Clean_Query'] == query].sort_values('Sample_MB')

    x = np.arange(len(sub))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 6))
    bars1 = ax.bar(x - width / 2, sub[error_col], width, label='Relative Error (%)')
    bars2 = ax.bar(x + width / 2, sub[overhead_col], width, label='Speed Overhead (%)')

    ax.set_xlabel('Sample Size (MB)')
    ax.set_ylabel('Percentage')
    ax.set_title(f'Relative Error and Speed Overhead per Sample DB (Query {idx + 1})')
    ax.set_xticks(x)
    ax.set_xticklabels([f"{int(mb)}MB" for mb in sub['Sample_MB']])
    ax.legend()

    for bar in bars1 + bars2:
        height = bar.get_height()
        if not pd.isna(height):
            ax.annotate(f'{height:.1f}%',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3),
                        textcoords="offset points",
                        ha='center', va='bottom')

    plt.tight_layout()
    filename = f"query_{idx + 1}.png"
    filepath = os.path.join(output_folder, filename)
    plt.savefig(filepath)
    plt.show()
